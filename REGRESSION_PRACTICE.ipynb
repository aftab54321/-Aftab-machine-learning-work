# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#data gathering
data=pd.read_csv("FuelConsumption.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.5+ KB

# %%
data.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
#data pre-processing
data.drop(columns=["MODELYEAR", "MAKE","VEHICLECLASS","FUELTYPE"],inplace=True)

# %%
data.head()
# Out:
#         MODEL  ENGINESIZE  CYLINDERS TRANSMISSION  FUELCONSUMPTION_CITY  \
# 0         ILX         2.0          4          AS5                   9.9
# 1         ILX         2.4          4           M6                  11.2
# 2  ILX HYBRID         1.5          4          AV7                   6.0
# 3     MDX 4WD         3.5          6          AS6                  12.7
# 4     RDX AWD         3.5          6          AS6                  12.1
#
#    FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 0                  6.7                   8.5                        33
# 1                  7.7                   9.6                        29
# 2                  5.8                   5.9                        48
# 3                  9.1                  11.1                        25
# 4                  8.7                  10.6                        27
#
#    CO2EMISSIONS
# 0           196
# 1           221
# 2           136
# 3           255
# 4           244

# %%
data.drop(columns=["MODEL"],inplace=True)

# %%
data.head()
# Out:
#    ENGINESIZE  CYLINDERS TRANSMISSION  FUELCONSUMPTION_CITY  \
# 0         2.0          4          AS5                   9.9
# 1         2.4          4           M6                  11.2
# 2         1.5          4          AV7                   6.0
# 3         3.5          6          AS6                  12.7
# 4         3.5          6          AS6                  12.1
#
#    FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 0                  6.7                   8.5                        33
# 1                  7.7                   9.6                        29
# 2                  5.8                   5.9                        48
# 3                  9.1                  11.1                        25
# 4                  8.7                  10.6                        27
#
#    CO2EMISSIONS
# 0           196
# 1           221
# 2           136
# 3           255
# 4           244

# %%
#data visualise
plt.scatter(data[["ENGINESIZE"]],data[["CO2EMISSIONS"]])
plt.show()

# %%
data.columns
# Out:
# Index(['ENGINESIZE', 'CYLINDERS', 'TRANSMISSION', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
#feature engineering
X=data[["ENGINESIZE","CYLINDERS", "FUELCONSUMPTION_CITY","FUELCONSUMPTION_COMB","FUELCONSUMPTION_COMB_MPG"]]
Y=data[["CO2EMISSIONS"]]
X
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_COMB  \
# 0            2.0          4                   9.9                   8.5
# 1            2.4          4                  11.2                   9.6
# 2            1.5          4                   6.0                   5.9
# 3            3.5          6                  12.7                  11.1
# 4            3.5          6                  12.1                  10.6
# ...          ...        ...                   ...                   ...
# 1062         3.0          6                  13.4                  11.8
# 1063         3.2          6                  13.2                  11.5
# 1064         3.0          6                  13.4                  11.8
# 1065         3.2          6                  12.9                  11.3
# 1066         3.2          6                  14.9                  12.8
#
#       FUELCONSUMPTION_COMB_MPG
# 0                           33
# 1                           29
# 2                           48
# 3                           25
# 4                           27
# ...                        ...
# 1062                        24
# 1063                        25
# 1064                        24
# 1065                        25
# 1066                        22
#
# [1067 rows x 5 columns]

# %%
corr=data.corr()

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#                           ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# ENGINESIZE                  1.000000   0.934011              0.832225
# CYLINDERS                   0.934011   1.000000              0.796473
# FUELCONSUMPTION_CITY        0.832225   0.796473              1.000000
# FUELCONSUMPTION_HWY         0.778746   0.724594              0.965718
# FUELCONSUMPTION_COMB        0.819482   0.776788              0.995542
# FUELCONSUMPTION_COMB_MPG   -0.808554  -0.770430             -0.935613
# CO2EMISSIONS                0.874154   0.849685              0.898039
#
#                           FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# ENGINESIZE                           0.778746              0.819482
# CYLINDERS                            0.724594              0.776788
# FUELCONSUMPTION_CITY                 0.965718              0.995542
# FUELCONSUMPTION_HWY                  1.000000              0.985804
# FUELCONSUMPTION_COMB                 0.985804              1.000000
# FUELCONSUMPTION_COMB_MPG            -0.893809             -0.927965
# CO2EMISSIONS                         0.861748              0.892129
#
#                           FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# ENGINESIZE                               -0.808554      0.874154
# CYLINDERS                                -0.770430      0.849685
# FUELCONSUMPTION_CITY                     -0.935613      0.898039
# FUELCONSUMPTION_HWY                      -0.893809      0.861748
# FUELCONSUMPTION_COMB                     -0.927965      0.892129
# FUELCONSUMPTION_COMB_MPG                  1.000000     -0.906394
# CO2EMISSIONS                             -0.906394      1.000000

# %%
#spliting data training and test set
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
Xtrain.shape
# Out:
# (853, 5)

# %%
Xtest.shape
# Out:
# (214, 5)

# %%
#choosing model
from sklearn.linear_model import LinearRegression

#model init
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
#model fit
model.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
theta0=model.intercept_
theta0
# Out:
# array([255.39945866])

# %%
theta1=model.coef_
theta1
# Out:
# array([[ 9.39780379,  7.91764532, -7.24567513, 10.65483522, -3.90135127]])

# %%
Xtrain
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_COMB  \
# 270          3.6          6                  14.6                  12.6
# 1006         4.6          8                  16.9                  15.1
# 728          3.5          6                  12.1                  10.6
# 992          2.5          4                  10.6                   9.5
# 702          1.5          4                   8.0                   7.4
# ...          ...        ...                   ...                   ...
# 1033         2.0          4                   7.9                   6.9
# 763          3.5          6                  17.8                  16.0
# 835          3.7          6                  13.5                  11.7
# 559          5.0          8                  15.8                  13.3
# 684          3.7          6                  13.1                  11.4
#
#       FUELCONSUMPTION_COMB_MPG
# 270                         22
# 1006                        19
# 728                         27
# 992                         30
# 702                         38
# ...                        ...
# 1033                        41
# 763                         18
# 835                         24
# 559                         21
# 684                         25
#
# [853 rows x 5 columns]

# %%
Ytrain
# Out:
#       CO2EMISSIONS
# 270            290
# 1006           347
# 728            244
# 992            218
# 702            170
# ...            ...
# 1033           186
# 763            256
# 835            269
# 559            306
# 684            262
#
# [853 rows x 1 columns]

# %%
#prediction
yhat=model.predict(Xtest.values)
yhat
# Out:
# array([[340.72855292],
#        [209.56229143],
#        [224.33458931],
#        [227.8332717 ],
#        [176.77761109],
#        [300.89251037],
#        [209.90320744],
#        [272.4218347 ],
#        [204.63819214],
#        [325.82086963],
#        [285.23313956],
#        [364.98873175],
#        [215.88031496],
#        [296.01114657],
#        [171.98355593],
#        [281.38107845],
#        [340.33174785],
#        [211.89224699],
#        [256.30643813],
#        [372.93368919],
#        [190.21679481],
#        [227.48397597],
#        [255.0051764 ],
#        [229.80423667],
#        [136.37833367],
#        [270.2581167 ],
#        [272.51134443],
#        [350.29566504],
#        [293.87834189],
#        [ 92.7744588 ],
#        [337.66184424],
#        [229.81481748],
#        [286.95828495],
#        [249.28352648],
#        [190.21679481],
#        [196.5432549 ],
#        [308.37859871],
#        [217.62043898],
#        [232.07802974],
#        [251.29937119],
#        [185.29269551],
#        [188.91553308],
#        [202.4644896 ],
#        [171.01322568],
#        [313.36106158],
#        [197.02045485],
#        [239.02141619],
#        [182.45278904],
#        [373.73873644],
#        [371.42719913],
#        [319.33595543],
#        [320.67998066],
#        [279.37176324],
#        [128.7343875 ],
#        [223.6100218 ],
#        [182.45278904],
#        [298.23162334],
#        [161.03278187],
#        [260.58489883],
#        [207.25230494],
#        [205.32596996],
#        [204.4697535 ],
#        [215.267717  ],
#        [350.29566504],
#        [264.30128484],
#        [307.84808245],
#        [329.16762741],
#        [288.96354885],
#        [204.60140244],
#        [114.3170289 ],
#        [316.75709693],
#        [233.28051607],
#        [325.62371876],
#        [341.00205994],
#        [317.24118181],
#        [218.10922829],
#        [274.44766394],
#        [184.03820801],
#        [221.98186732],
#        [171.01322568],
#        [182.08970287],
#        [260.70061744],
#        [165.99961666],
#        [307.29782995],
#        [330.7720475 ],
#        [256.85852827],
#        [187.90680832],
#        [170.2986427 ],
#        [341.8276571 ],
#        [299.54162823],
#        [259.38717009],
#        [205.0786024 ],
#        [245.74958979],
#        [361.88366914],
#        [339.70984363],
#        [337.87051503],
#        [176.05304358],
#        [244.5178813 ],
#        [374.29735323],
#        [264.38021376],
#        [188.13824554],
#        [318.71902906],
#        [125.21668774],
#        [169.85823243],
#        [199.29365165],
#        [193.21455911],
#        [198.36445208],
#        [275.63885061],
#        [190.51093659],
#        [306.07952329],
#        [208.07636671],
#        [213.43493047],
#        [270.16516452],
#        [289.60110998],
#        [318.80199671],
#        [275.56990623],
#        [312.24880383],
#        [256.45431143],
#        [350.07892936],
#        [201.85100569],
#        [266.94814861],
#        [192.09635556],
#        [344.81449776],
#        [135.08652974],
#        [182.45278904],
#        [295.17245269],
#        [290.07176787],
#        [294.95313166],
#        [270.45115941],
#        [265.1515555 ],
#        [246.88462655],
#        [303.54341287],
#        [187.89682378],
#        [133.2913619 ],
#        [375.18787147],
#        [347.44674198],
#        [274.44766394],
#        [ 90.89489804],
#        [203.16849177],
#        [235.70663355],
#        [302.71287845],
#        [190.21679481],
#        [361.88366914],
#        [337.87051503],
#        [189.8758788 ],
#        [184.15392662],
#        [270.59903271],
#        [330.9904294 ],
#        [314.76746111],
#        [149.10513549],
#        [182.45278904],
#        [261.37841072],
#        [162.67092088],
#        [246.19625245],
#        [314.60900701],
#        [252.70577072],
#        [283.47180076],
#        [212.41218244],
#        [331.10865136],
#        [247.05710392],
#        [177.48595425],
#        [206.52773743],
#        [176.76138674],
#        [235.15847202],
#        [253.93969288],
#        [201.08370268],
#        [294.3589843 ],
#        [184.86226978],
#        [357.15609643],
#        [366.3427541 ],
#        [262.37494986],
#        [275.2979346 ],
#        [250.17058683],
#        [313.0241843 ],
#        [293.70116008],
#        [268.07442963],
#        [266.30654875],
#        [254.66426039],
#        [184.86226978],
#        [326.07631464],
#        [317.80855719],
#        [182.98270902],
#        [321.62787992],
#        [201.85100569],
#        [306.17717991],
#        [288.84849594],
#        [199.34042588],
#        [326.83707558],
#        [184.86226978],
#        [306.91484415],
#        [270.54881602],
#        [268.92066155],
#        [254.10813152],
#        [243.25120817],
#        [217.72557678],
#        [294.67369143],
#        [237.29781878],
#        [215.93552575],
#        [245.5852593 ],
#        [321.62787992],
#        [265.62471673],
#        [219.75140603],
#        [235.46099352],
#        [332.51505089],
#        [293.8942028 ],
#        [293.27477309],
#        [285.12556784],
#        [257.98077055],
#        [343.26123347],
#        [199.19415739],
#        [216.03502001],
#        [190.51093659],
#        [184.86226978],
#        [182.98270902]])

# %%
Ytest.head(1)
# Out:
#      CO2EMISSIONS
# 766           356

# %%
#error validation
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error

# %%
mean_squared_error(yhat,Ytest)
# Out:
# 439.41004482673964

# %%
100-mean_absolute_percentage_error(yhat,Ytest)*100
# Out:
# 94.94756190474935

# %%
#kfold cross validation
from sklearn.model_selection import KFold
low=0
up=data.shape[0]
folds=KFold(n_splits=3)
fold=0

for train,test in folds.split(range(low,up)):
    #training data
    x=X.iloc[train]
    y=Y.iloc[train]

    #testing data
    xt=X.iloc[test]
    yt=Y.iloc[test]

    #model initialize
    model=LinearRegression()

    #model fit
    model.fit(x,y)

    #model test
    yhat=model.predict(xt.values)
    fold+=1

    #evaluation
    print(f"Fold{fold} ")
    print("MSE: ",mean_squared_error(yhat,yt))
    print("MAE: ",100-mean_absolute_percentage_error(yhat,yt)*100)
    print("==========================")
# Out:
# Fold1
# MSE:  575.0074513590172
# MAE:  94.77847972913341
# ==========================
# Fold2
# MSE:  560.5419857477442
# MAE:  94.51023376017352
# ==========================
# Fold3
# MSE:  272.3304932249998
# MAE:  95.32873137778503
# ==========================
